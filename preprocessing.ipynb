# %%
#Preprocessing the Data
# =========================
# Step 0: Install dependencies
# =========================
# !pip install Pillow tqdm

# =========================
# Step 1: Clone your GitHub repo
# =========================
# Replace with your GitHub repo URL
# !git clone https://github.com/Nayanapmku/facial_recognition.git

import os
repo_dir = "facial_recognition"  # Replace with your cloned repo folder
os.chdir(repo_dir)

# Check the contents
# !ls
# You should see 'dataset/' folder here

# =========================
# Step 2: Imports
# =========================
from PIL import Image
from tqdm import tqdm

# =========================
# Step 3: Define input/output paths
# =========================
dataset_dir = "dataset"  # The folder in your repo containing train/val/test
processed_dir = "processed_data"  # New folder to store preprocessed images
os.makedirs(processed_dir, exist_ok=True)

target_size = (224, 224)  # Resize images
mode = "RGB"               # Convert to RGB

# =========================
# Step 4: Preprocess function
# =========================
def preprocess_and_save(input_dir, output_dir):
    for split in os.listdir(input_dir):  # train, val, test
        split_input_dir = os.path.join(input_dir, split)
        split_output_dir = os.path.join(output_dir, split)
        os.makedirs(split_output_dir, exist_ok=True)

        for person in os.listdir(split_input_dir):
            person_input_dir = os.path.join(split_input_dir, person)
            person_output_dir = os.path.join(split_output_dir, person)
            os.makedirs(person_output_dir, exist_ok=True)

            for img_file in tqdm(os.listdir(person_input_dir), desc=f"Processing {split}/{person}"):
                img_path = os.path.join(person_input_dir, img_file)
                try:
                    img = Image.open(img_path).convert(mode)
                    img = img.resize(target_size)
                    save_path = os.path.join(person_output_dir, img_file)
                    img.save(save_path)
                except Exception as e:
                    print(f"Failed to process {img_path}: {e}")

# =========================
# Step 5: Run preprocessing
# =========================
preprocess_and_save(dataset_dir, processed_dir)
print("✅ Preprocessing complete! Check the processed_data folder.")

# !zip -r processed_data.zip processed_data
from google.colab import files
files.download("processed_data.zip")
     
Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
Cloning into 'facial_recognition'...
remote: Enumerating objects: 216, done.
remote: Counting objects: 100% (216/216), done.
remote: Compressing objects: 100% (206/206), done.
remote: Total 216 (delta 17), reused 0 (delta 0), pack-reused 0 (from 0)
Receiving objects: 100% (216/216), 820.19 KiB | 4.69 MiB/s, done.
Resolving deltas: 100% (17/17), done.
dataset  processed_data  README.md
Processing Facial_Recognition_Val/John_Snow: 100%|██████████| 3/3 [00:00<00:00, 20.07it/s]
Processing Facial_Recognition_Val/Jacques_Rogge: 100%|██████████| 2/2 [00:00<00:00, 181.41it/s]
Processing Facial_Recognition_Val/Kim_Clijsters: 100%|██████████| 3/3 [00:00<00:00, 168.76it/s]
Processing Facial_Recognition_Val/Jennifer_Garner: 100%|██████████| 3/3 [00:00<00:00, 134.62it/s]
Processing Facial_Recognition_Train/John_Snow: 100%|██████████| 11/11 [00:00<00:00, 217.90it/s]
Processing Facial_Recognition_Train/Jacques_Rogge: 100%|██████████| 6/6 [00:00<00:00, 128.79it/s]
Processing Facial_Recognition_Train/Kim_Clijsters: 100%|██████████| 8/8 [00:00<00:00, 144.85it/s]
Processing Facial_Recognition_Train/Jennifer_Garner: 100%|██████████| 7/7 [00:00<00:00, 109.79it/s]
Processing Facial_Recognition_Test/John_Snow: 100%|██████████| 3/3 [00:00<00:00, 143.98it/s]
Processing Facial_Recognition_Test/Jacques_Rogge: 100%|██████████| 2/2 [00:00<00:00, 244.92it/s]
Processing Facial_Recognition_Test/Kim_Clijsters: 100%|██████████| 3/3 [00:00<00:00, 221.92it/s]
Processing Facial_Recognition_Test/Jennifer_Garner: 100%|██████████| 2/2 [00:00<00:00, 237.88it/s]
✅ Preprocessing complete! Check the processed_data folder.
  adding: processed_data/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/John_Snow/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/John_Snow/John_Snow_0016.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/John_Snow/John_Snow_0017.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/John_Snow/John_Snow_0015.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Jacques_Rogge/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/Jacques_Rogge/Jacques_Rogge_0009.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Jacques_Rogge/Jacques_Rogge_0010.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Kim_Clijsters/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/Kim_Clijsters/Kim_Clijsters_0013.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Kim_Clijsters/Kim_Clijsters_0014.jpg (deflated 1%)
  adding: processed_data/Facial_Recognition_Val/Kim_Clijsters/Kim_Clijsters_0012.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Jennifer_Garner/ (stored 0%)
  adding: processed_data/Facial_Recognition_Val/Jennifer_Garner/Jennifer_Garner_0011.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Jennifer_Garner/Jennifer_Garner_0012.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Val/Jennifer_Garner/Jennifer_Garner_0010.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/ (stored 0%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/ (stored 0%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0005.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0010.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0001.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0008.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0002.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0004.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0006.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0009.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0007.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0011.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/John_Snow/John_Snow_0003.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/ (stored 0%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0003.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0002.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0005.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0006.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0004.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jacques_Rogge/Jacques_Rogge_0001.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/ (stored 0%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0008.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0004.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0002.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0006.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0005.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0007.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0001.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Kim_Clijsters/Kim_Clijsters_0003.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/ (stored 0%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0004.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0006.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0005.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0002.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0007.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0003.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Train/Jennifer_Garner/Jennifer_Garner_0001.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/ (stored 0%)
  adding: processed_data/Facial_Recognition_Test/John_Snow/ (stored 0%)
  adding: processed_data/Facial_Recognition_Test/John_Snow/John_Snow_0014.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/John_Snow/John_Snow_0013.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/John_Snow/John_Snow_0012.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Jacques_Rogge/ (stored 0%)
  adding: processed_data/Facial_Recognition_Test/Jacques_Rogge/Jacques_Rogge_0008.jpg (deflated 3%)
  adding: processed_data/Facial_Recognition_Test/Jacques_Rogge/Jacques_Rogge_0007.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Kim_Clijsters/ (stored 0%)
  adding: processed_data/Facial_Recognition_Test/Kim_Clijsters/Kim_Clijsters_0009.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Kim_Clijsters/Kim_Clijsters_0010.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Kim_Clijsters/Kim_Clijsters_0011.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Jennifer_Garner/ (stored 0%)
  adding: processed_data/Facial_Recognition_Test/Jennifer_Garner/Jennifer_Garner_0008.jpg (deflated 2%)
  adding: processed_data/Facial_Recognition_Test/Jennifer_Garner/Jennifer_Garner_0009.jpg (deflated 2%)
